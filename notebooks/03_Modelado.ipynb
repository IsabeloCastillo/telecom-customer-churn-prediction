# %% [markdown]
# # Predicción de Abandono de Clientes en Telecomunicaciones
#
# ## Notebook 3 - Análisis Exploratorio de Datos (EDA)
#
# ### Objetivo del notebook
#
# El objetivo de este notebook es realizar un análisis exploratorio del conjunto de datos previamente preparado para comprender las características de los clientes, identificar patrones, detectar relaciones entre las variables y obtener información útil que sirva de base para la construcción del modelo predictivo.
#
# ---
#
# ## Desarrollo
